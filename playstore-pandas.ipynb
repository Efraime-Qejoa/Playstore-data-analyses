# %%
# Importing libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
playstore_data = pd.read_csv('googleplaystore.csv')
array_list = np.genfromtxt("googleplaystore.txt", delimiter=' , ', skip_header=1)
# snsvisual_data = sns.load_dataset('googleplaystore.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-de715cf1095c> in <module>
# ----> 1 playstore_data = pd.read_csv('googleplaystore.csv')
#       2 array_list = np.genfromtxt("googleplaystore.txt", delimiter=' , ', skip_header=1)
#       3 # snsvisual_data = sns.load_dataset('googleplaystore.csv')
#
# NameError: name 'pd' is not defined

# %%
# Display values
playstore_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# describing table

playstore_data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# Table columns

playstore_data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# locate row
playstore_data.drop[]

# %%
# Shape of table

# number of rows & columns

playstore_data.shape
# Out:
# (10841, 13)

# %%
# Filtering columns
filter_columns = playstore_data['Category']

# %%
# Filtering columns
installs_data = playstore_data['Installs']

# %%
installs_data
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
filter_columns
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %%
filtered_data_head = playstore_data.head(10841)

# %%
filtered_data_head
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#plt.bar(installs_data,filter_columns );

# %%
plt.figure(figsize=(20,100))
plt.ylabel=('Installs')
plt.xlabel=('Categories')
sns.countplot(y='Category', data=filtered_data_head);

# %%
# Retriving specific record
playstore_data.at[124, 'App'],
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5caab57cd421> in <module>
#       1 # Retriving specific record
# ----> 2 playstore_data.at[124, 'App'],
#
# NameError: name 'playstore_data' is not defined

# %%
# Retriving specific record
playstore_data.at[125, 'App'],
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0d19ec4e01e7> in <module>
#       1 # Retriving specific record
# ----> 2 playstore_data.at[125, 'App'],
#
# NameError: name 'playstore_data' is not defined
